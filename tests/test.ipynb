# %%
# %load_ext autoreload
# %autoreload 2

import sqlite3
import duckdb
import numpy as np
import pandas as pd
import pyopenms as poms

pd.set_option('display.float_format', '{:.15f}'.format)

from pyprophet.io.dispatcher import  ReaderDispatcher
from pyprophet.io.scoring.osw import OSWReader
from pyprophet.io.scoring.parquet import ParquetReader
from pyprophet.io.scoring.split_parquet import SplitParquetReader
from pyprophet.io.scoring.tsv import TSVReader  # legacy, limited support
from pyprophet._config import RunnerIOConfig, RunnerConfig, IPFIOConfig

# %%
conn_duck = duckdb.connect(':memory:')

query = """
WITH normalized_peptides AS (
                SELECT 
                    ID AS PEPTIDE_ID,
                    REPLACE(
                        REPLACE(
                            REPLACE(
                                REPLACE(MODIFIED_SEQUENCE, '(UniMod:1)', '(Acetyl)'),
                            '(UniMod:35)', '(Oxidation)'),
                        '(UniMod:21)', '(Phospho)'),
                    '(UniMod:4)', '(Carbamidomethyl)') AS NORMALIZED_SEQUENCE
                FROM sqlite_scan('./data/test_data.osw', 'PEPTIDE')
            ),
            ipf_groups AS (
                SELECT 
                    NORMALIZED_SEQUENCE,
                    MIN(PEPTIDE_ID) AS IPF_PEPTIDE_ID
                FROM normalized_peptides
                GROUP BY NORMALIZED_SEQUENCE
            ),
            peptide_ipf_map AS (
                SELECT 
                    np.PEPTIDE_ID,
                    g.IPF_PEPTIDE_ID
                FROM normalized_peptides np
                JOIN ipf_groups g USING (NORMALIZED_SEQUENCE)
            ) 

SELECT * FROM peptide_ipf_map"""

ipf_peptide_map = conn_duck.execute(query).df()
ipf_peptide_map
# Out:
#       PEPTIDE_ID  IPF_PEPTIDE_ID
# 0              0               0
# 1              1               1
# 2              2               2
# 3              3               3
# 4              5               5
# ...          ...             ...
# 1365        1288            1288
# 1366         479             479
# 1367        1086            1086
# 1368         764             764
# 1369        1143            1143
#
# [1370 rows x 2 columns]

# %%
conn = sqlite3.connect("./data/test_data.osw")
peptide_table = pd.read_sql_query("SELECT * FROM PEPTIDE", conn)

peptide_table
# Out:
#         ID UNMODIFIED_SEQUENCE                   MODIFIED_SEQUENCE  DECOY
# 0        0      AACNNQGQQIAEHR  AACNNQGQQIAEHR(Label:13C(6)15N(4))      0
# 1        1          AAEDFTLLVK      AAEDFTLLVK(Label:13C(6)15N(2))      0
# 2        2          AAEDFTLLVK              AAEDFTLLVK(UniMod:259)      0
# 3        3        AAEPFLDALLAR            AAEPFLDALLAR(UniMod:267)      0
# 4        4      AAGASAQVLGQEGK  AAGASAQVLGQEGK(Label:13C(6)15N(2))      0
# ...    ...                 ...                                 ...    ...
# 1365  1365          YVQDGTYTAK      YVQDGTYTAK(Label:13C(6)15N(2))      0
# 1366  1366          YVQDGTYTAK              YVQDGTYTAK(UniMod:259)      0
# 1367  1367         YVWSYNSDAPR             YVWSYNSDAPR(UniMod:267)      0
# 1368  1368         YYDYTLSINGK     YYDYTLSINGK(Label:13C(6)15N(2))      0
# 1369  1369         YYDYTLSINGK             YYDYTLSINGK(UniMod:259)      0
#
# [1370 rows x 4 columns]

# %%
def unimod_to_codename(seq):
    """
    Convert a sequence with unimod modifications to a codename.
    This is a placeholder function; actual implementation may vary.
    """
    seq_poms = poms.AASequence.fromString(seq)
    codename = seq_poms.toString()
    return codename

# %%
# apply the conversion to the MODIFIED_SEQUENCE column and create a new column
peptide_table['codename'] = peptide_table['MODIFIED_SEQUENCE'].apply(unimod_to_codename)

# filter for MODIFIED_SEQUENCE wiht UniMod in sequence
unimod_peptide_table = peptide_table[peptide_table['MODIFIED_SEQUENCE'].str.contains('UniMod')]

# Perform oppisite operation to get the original sequence
codename_peptide_table = peptide_table[ ~peptide_table['MODIFIED_SEQUENCE'].str.contains('UniMod')]

# Merge the two DataFrames on the 'codename' column
merged_peptide_table = pd.merge(unimod_peptide_table[['codename', 'ID']], codename_peptide_table[['codename', 'ID']], on='codename', suffixes=('_unimod', '_codename'), how='outer')

# Fill NaN values in the 'ID_codename' column with the 'ID_unimod' values
merged_peptide_table['ID_codename'] = merged_peptide_table['ID_codename'].fillna(merged_peptide_table['ID_unimod'])
# Fill NaN values in the 'ID_unimod' column with the 'ID_codename' values
merged_peptide_table['ID_unimod'] = merged_peptide_table['ID_unimod'].fillna(merged_peptide_table['ID_codename'])

# Convert both 'ID_unimod' and 'ID_codename' columns to integer type
merged_peptide_table['ID_unimod'] = merged_peptide_table['ID_unimod'].astype(int)
merged_peptide_table['ID_codename'] = merged_peptide_table['ID_codename'].astype(int)

merged_peptide_table
# Out:
#                                  codename  ID_unimod  ID_codename
# 0      AACNNQGQQIAEHR(Label:13C(6)15N(4))          0            0
# 1          AAEDFTLLVK(Label:13C(6)15N(2))          2            1
# 2        AAEPFLDALLAR(Label:13C(6)15N(4))          3            3
# 3      AAGASAQVLGQEGK(Label:13C(6)15N(2))          5            4
# 4          AAGNEDDLER(Label:13C(6)15N(4))          6            6
# ...                                   ...        ...          ...
# 1023     YVILQLLSGETR(Label:13C(6)15N(4))       1362         1361
# 1024  YVPIHTIDDGYSVIK(Label:13C(6)15N(2))       1364         1363
# 1025       YVQDGTYTAK(Label:13C(6)15N(2))       1366         1365
# 1026      YVWSYNSDAPR(Label:13C(6)15N(4))       1367         1367
# 1027      YYDYTLSINGK(Label:13C(6)15N(2))       1369         1368
#
# [1028 rows x 3 columns]

# %%
merged_peptide_table[ merged_peptide_table["ID_unimod"]==125]
# Out:
#                               codename  ID_unimod  ID_codename
# 92  ASTLTIVTDTGPDR(Label:13C(6)15N(4))      125.0          NaN

# %% [markdown]
# # Scoring

# %%
def create_reader_config(level, infile, outfile):
    """
    Common config generator to avoid repetition
    """
    return RunnerIOConfig(
        infile=infile,
        outfile=outfile,
        subsample_ratio=1,
        context="score_learn",
        level=level,
        runner=RunnerConfig(
        ),
    )

# %% [markdown]
# ## MS1MS2

# %%
osw_config = create_reader_config(
    "ms1ms2", "data/test_data.osw", "data/test_data.osw"
)
parquet_config = create_reader_config(
    "ms1ms2", "data/test_data.parquet", "data/test_data.parquet"
)
split_parquet_config = create_reader_config(
    "ms1ms2",
    "data/test_data.oswpq",
    "data/test_data.oswpq",
)

osw_reader = ReaderDispatcher.get_reader(osw_config)
parquet_reader = ReaderDispatcher.get_reader(parquet_config)
split_parquet_reader = ReaderDispatcher.get_reader(split_parquet_config)

cols = ['run_id', 'feature_id', 'decoy', 'main_var_xcorr_shape']
osw_data = osw_reader.read().sort_values(by=cols).reset_index(drop=True)
parquet_data = parquet_reader.read().sort_values(by=cols).reset_index(drop=True)
split_parquet_data = split_parquet_reader.read().sort_values(by=cols).reset_index(drop=True)
# Out:
# 2025-06-02 00:34:55.147 | WARNING  | pyprophet.io.dispatcher:get_reader:100 - Parquet input is experimental. Proceed with caution.
# 2025-06-02 00:34:55.148 | WARNING  | pyprophet.io.dispatcher:get_reader:103 - Split parquet input is experimental. Proceed with caution.
# 2025-06-02 00:34:55.429 | INFO     | pyprophet.io.util:print_parquet_tree:311 - Detected 1 split_parquet run files
# 2025-06-02 00:34:55.430 | INFO     | pyprophet.io.util:print_parquet_tree:312 - Input Parquet Structure:
# └── 📁 data/test_data.oswpq
#     ├── 📁 test_data.oswpq
#     │   ├── 📄 precursors_features.parquet
#     │   └── 📄 transition_features.parquet

# %%
osw_data
# Out:
#                feature_id  area_intensity  apex_intensity  var_bseries_score  \
# 0    -9211032279639747263          8969.0          1401.0                1.0
# 1    -9209834744278112856          5275.0          1672.0                1.0
# 2    -9204568338203974043         32824.0          5721.0                4.0
# 3    -9202066408251325127          7158.0           947.0                5.0
# 4    -9194114845888269381          9826.0          2161.0                4.0
# ...                   ...             ...             ...                ...
# 3405  9204571350293509371         23649.0          3193.0                7.0
# 3406  9204761823691693843         66548.0          4605.0                2.0
# 3407  9218597765662578237         55289.0         11128.0                6.0
# 3408  9219889606523665288         18025.0          2431.0                4.0
# 3409  9222703966483715396          2747.0           486.0                5.0
#
#       var_dotprod_score  var_intensity_score  var_isotope_correlation_score  \
# 0              0.600952             0.040370                       0.855669
# 1              0.675908             0.107070                       0.920075
# 2              0.802029             0.191046                       0.854679
# 3              0.816020             0.016773                       0.255529
# 4              0.632115             0.025071                       0.181583
# ...                 ...                  ...                            ...
# 3405           0.658018             0.048516                       0.805307
# 3406           0.688721             0.113038                      -0.021843
# 3407           0.789868             0.271694                       0.990321
# 3408           0.617810             0.031256                       0.599238
# 3409           0.740998             0.022376                       0.277807
#
#       var_isotope_overlap_score  var_library_corr  var_library_dotprod  ...  \
# 0                      0.092987         -0.417037             0.788891  ...
# 1                      0.148815         -0.796921             0.674237  ...
# 2                      0.000000          0.545997             0.905890  ...
# 3                      0.277871          0.982370             0.997704  ...
# 4                      0.853145          0.834004             0.989984  ...
# ...                         ...               ...                  ...  ...
# 3405                   0.065161         -0.661946             0.845153  ...
# 3406                   0.000000         -0.073519             0.773383  ...
# 3407                   0.000000          0.834778             0.974048  ...
# 3408                   0.904466         -0.349098             0.916917  ...
# 3409                   0.675646         -0.370653             0.950788  ...
#
#         exp_rt  precursor_charge  decoy  transition_count  \
# 0     1793.450                 2      0                 4
# 1      457.673                 2      1                 4
# 2     1509.490                 2      1                 4
# 3     3133.200                 2      0                 4
# 4     2219.430                 2      0                 4
# ...        ...               ...    ...               ...
# 3405  4244.440                 2      1                 4
# 3406  1715.920                 2      1                 4
# 3407  2889.390                 2      0                 4
# 3408  1732.890                 2      0                 4
# 3409  4481.570                 2      1                 4
#
#                       group_id  var_ms1_massdev_score  \
# 0      -8670811102654834151_62               6.843700
# 1     -8670811102654834151_470              20.641658
# 2     -8670811102654834151_664              10.202549
# 3     -8670811102654834151_265               6.245661
# 4     -8670811102654834151_217              11.232396
# ...                        ...                    ...
# 3405  -8670811102654834151_582              16.097756
# 3406  -8670811102654834151_363               1.847235
# 3407  -8670811102654834151_134               1.192150
# 3408  -8670811102654834151_273               1.595447
# 3409  -8670811102654834151_423               2.384041
#
#       var_ms1_isotope_correlation_score  var_ms1_isotope_overlap_score  \
# 0                              0.934914                       0.507910
# 1                             -0.423074                       0.571429
# 2                             -0.081574                       1.077040
# 3                             -0.639745                       2.426517
# 4                              0.401923                       1.510283
# ...                                 ...                            ...
# 3405                           0.948893                       4.148277
# 3406                          -0.698961                       1.384799
# 3407                           0.986200                       0.104489
# 3408                          -0.503802                       0.274504
# 3409                           0.255523                       0.941265
#
#       var_ms1_xcorr_coelution  var_ms1_xcorr_shape
# 0                    6.736079             0.493892
# 1                    2.816497             0.700567
# 2                    4.160247             0.577194
# 3                    6.207427             0.413703
# 4                    3.632993             0.501500
# ...                       ...                  ...
# 3405                 4.642969             0.623494
# 3406                10.242641             0.474553
# 3407                 0.000000             0.958779
# 3408                 4.112908             0.684720
# 3409                 5.379956             0.576366
#
# [3410 rows x 43 columns]

# %%
parquet_data
# Out:
#                       group_id           feature_id protein_id  \
# 0      -8670811102654834151_62 -9211032279639747263        [2]
# 1     -8670811102654834151_470 -9209834744278112856       [21]
# 2     -8670811102654834151_664 -9204568338203974043       [31]
# 3     -8670811102654834151_265 -9202066408251325127       [12]
# 4     -8670811102654834151_217 -9194114845888269381       [10]
# ...                        ...                  ...        ...
# 3405  -8670811102654834151_582  9204571350293509371       [27]
# 3406  -8670811102654834151_363  9204761823691693843       [17]
# 3407  -8670811102654834151_134  9218597765662578237        [6]
# 3408  -8670811102654834151_273  9219889606523665288       [12]
# 3409  -8670811102654834151_423  9222703966483715396       [19]
#
#                    run_id  precursor_id  precursor_charge    exp_rt  decoy  \
# 0    -8670811102654834151            62                 2  1793.450  False
# 1    -8670811102654834151           470                 2   457.673   True
# 2    -8670811102654834151           664                 2  1509.490   True
# 3    -8670811102654834151           265                 2  3133.200  False
# 4    -8670811102654834151           217                 2  2219.430  False
# ...                   ...           ...               ...       ...    ...
# 3405 -8670811102654834151           582                 2  4244.440   True
# 3406 -8670811102654834151           363                 2  1715.920   True
# 3407 -8670811102654834151           134                 2  2889.390  False
# 3408 -8670811102654834151           273                 2  1732.890  False
# 3409 -8670811102654834151           423                 2  4481.570   True
#
#       area_intensity  apex_intensity  ...  var_sonar_log_sn  \
# 0             8969.0          1401.0  ...               NaN
# 1             5275.0          1672.0  ...               NaN
# 2            32824.0          5721.0  ...               NaN
# 3             7158.0           947.0  ...               NaN
# 4             9826.0          2161.0  ...               NaN
# ...              ...             ...  ...               ...
# 3405         23649.0          3193.0  ...               NaN
# 3406         66548.0          4605.0  ...               NaN
# 3407         55289.0         11128.0  ...               NaN
# 3408         18025.0          2431.0  ...               NaN
# 3409          2747.0           486.0  ...               NaN
#
#       var_sonar_log_diff  var_sonar_log_trend  var_sonar_rsq  \
# 0                    NaN                  NaN            NaN
# 1                    NaN                  NaN            NaN
# 2                    NaN                  NaN            NaN
# 3                    NaN                  NaN            NaN
# 4                    NaN                  NaN            NaN
# ...                  ...                  ...            ...
# 3405                 NaN                  NaN            NaN
# 3406                 NaN                  NaN            NaN
# 3407                 NaN                  NaN            NaN
# 3408                 NaN                  NaN            NaN
# 3409                 NaN                  NaN            NaN
#
#       transition_count  var_ms1_massdev_score  \
# 0                    4               6.843699
# 1                    4              20.641659
# 2                    4              10.202549
# 3                    4               6.245661
# 4                    4              11.232396
# ...                ...                    ...
# 3405                 4              16.097755
# 3406                 4               1.847235
# 3407                 4               1.192150
# 3408                 4               1.595447
# 3409                 4               2.384041
#
#       var_ms1_isotope_correlation_score  var_ms1_isotope_overlap_score  \
# 0                              0.934914                       0.507910
# 1                             -0.423074                       0.571429
# 2                             -0.081574                       1.077040
# 3                             -0.639745                       2.426517
# 4                              0.401923                       1.510283
# ...                                 ...                            ...
# 3405                           0.948893                       4.148277
# 3406                          -0.698961                       1.384799
# 3407                           0.986200                       0.104489
# 3408                          -0.503802                       0.274504
# 3409                           0.255523                       0.941265
#
#       var_ms1_xcorr_coelution  var_ms1_xcorr_shape
# 0                    6.736079             0.493892
# 1                    2.816497             0.700567
# 2                    4.160247             0.577194
# 3                    6.207427             0.413703
# 4                    3.632993             0.501500
# ...                       ...                  ...
# 3405                 4.642970             0.623494
# 3406                10.242640             0.474553
# 3407                 0.000000             0.958779
# 3408                 4.112908             0.684720
# 3409                 5.379956             0.576366
#
# [3410 rows x 44 columns]

# %%
split_parquet_data
# Out:
#                       group_id           feature_id protein_id  \
# 0      -8670811102654834151_62 -9211032279639747263        [2]
# 1     -8670811102654834151_470 -9209834744278112856       [21]
# 2     -8670811102654834151_664 -9204568338203974043       [31]
# 3     -8670811102654834151_265 -9202066408251325127       [12]
# 4     -8670811102654834151_217 -9194114845888269381       [10]
# ...                        ...                  ...        ...
# 3405  -8670811102654834151_582  9204571350293509371       [27]
# 3406  -8670811102654834151_363  9204761823691693843       [17]
# 3407  -8670811102654834151_134  9218597765662578237        [6]
# 3408  -8670811102654834151_273  9219889606523665288       [12]
# 3409  -8670811102654834151_423  9222703966483715396       [19]
#
#                    run_id  precursor_id  precursor_charge    exp_rt  decoy  \
# 0    -8670811102654834151            62                 2  1793.450      0
# 1    -8670811102654834151           470                 2   457.673      1
# 2    -8670811102654834151           664                 2  1509.490      1
# 3    -8670811102654834151           265                 2  3133.200      0
# 4    -8670811102654834151           217                 2  2219.430      0
# ...                   ...           ...               ...       ...    ...
# 3405 -8670811102654834151           582                 2  4244.440      1
# 3406 -8670811102654834151           363                 2  1715.920      1
# 3407 -8670811102654834151           134                 2  2889.390      0
# 3408 -8670811102654834151           273                 2  1732.890      0
# 3409 -8670811102654834151           423                 2  4481.570      1
#
#       area_intensity  apex_intensity  ...  var_sonar_log_sn  \
# 0             8969.0          1401.0  ...               NaN
# 1             5275.0          1672.0  ...               NaN
# 2            32824.0          5721.0  ...               NaN
# 3             7158.0           947.0  ...               NaN
# 4             9826.0          2161.0  ...               NaN
# ...              ...             ...  ...               ...
# 3405         23649.0          3193.0  ...               NaN
# 3406         66548.0          4605.0  ...               NaN
# 3407         55289.0         11128.0  ...               NaN
# 3408         18025.0          2431.0  ...               NaN
# 3409          2747.0           486.0  ...               NaN
#
#       var_sonar_log_diff  var_sonar_log_trend  var_sonar_rsq  \
# 0                    NaN                  NaN            NaN
# 1                    NaN                  NaN            NaN
# 2                    NaN                  NaN            NaN
# 3                    NaN                  NaN            NaN
# 4                    NaN                  NaN            NaN
# ...                  ...                  ...            ...
# 3405                 NaN                  NaN            NaN
# 3406                 NaN                  NaN            NaN
# 3407                 NaN                  NaN            NaN
# 3408                 NaN                  NaN            NaN
# 3409                 NaN                  NaN            NaN
#
#       transition_count  var_ms1_massdev_score  \
# 0                    4               6.843700
# 1                    4              20.641658
# 2                    4              10.202549
# 3                    4               6.245661
# 4                    4              11.232396
# ...                ...                    ...
# 3405                 4              16.097756
# 3406                 4               1.847235
# 3407                 4               1.192150
# 3408                 4               1.595447
# 3409                 4               2.384041
#
#       var_ms1_isotope_correlation_score  var_ms1_isotope_overlap_score  \
# 0                              0.934914                       0.507910
# 1                             -0.423074                       0.571429
# 2                             -0.081574                       1.077040
# 3                             -0.639745                       2.426517
# 4                              0.401923                       1.510283
# ...                                 ...                            ...
# 3405                           0.948893                       4.148277
# 3406                          -0.698961                       1.384799
# 3407                           0.986200                       0.104489
# 3408                          -0.503802                       0.274504
# 3409                           0.255523                       0.941265
#
#       var_ms1_xcorr_coelution  var_ms1_xcorr_shape
# 0                    6.736079             0.493892
# 1                    2.816497             0.700567
# 2                    4.160247             0.577194
# 3                    6.207427             0.413703
# 4                    3.632993             0.501500
# ...                       ...                  ...
# 3405                 4.642969             0.623494
# 3406                10.242641             0.474553
# 3407                 0.000000             0.958779
# 3408                 4.112908             0.684720
# 3409                 5.379956             0.576366
#
# [3410 rows x 44 columns]

# %% [markdown]
# ## Transition

# %%
osw_config = create_reader_config(
    "transition", "data/test_data.osw", "data/test_data.osw"
)
parquet_config = create_reader_config(
    "transition", "data/test_data.parquet", "data/test_data.parquet"
)
split_parquet_config = create_reader_config(
    "transition",
    "data/test_data.oswpq",
    "data/test_data.oswpq",
)

osw_reader = ReaderDispatcher.get_reader(osw_config)
parquet_reader = ReaderDispatcher.get_reader(parquet_config)
split_parquet_reader = ReaderDispatcher.get_reader(split_parquet_config)

cols = ['run_id', 'feature_id', 'transition_id', 'decoy', 'main_var_xcorr_shape']
osw_data = osw_reader.read().sort_values(by=cols).reset_index(drop=True)
parquet_data = parquet_reader.read().sort_values(by=cols).reset_index(drop=True)
split_parquet_data = split_parquet_reader.read().sort_values(by=cols).reset_index(drop=True)
# Out:
# 2025-06-02 00:56:03.916 | WARNING  | pyprophet.io.dispatcher:get_reader:100 - Parquet input is experimental. Proceed with caution.
# 2025-06-02 00:56:03.917 | WARNING  | pyprophet.io.dispatcher:get_reader:103 - Split parquet input is experimental. Proceed with caution.
# 2025-06-02 00:56:04.534 | INFO     | pyprophet.io._base:_collapse_ipf_peptide_ids:1065 - Collapsed 13 of 6520 rows due to multiple transitions features mapping to different peptidoforms.
# 2025-06-02 00:56:04.612 | INFO     | pyprophet.io.util:print_parquet_tree:311 - Detected 1 split_parquet run files
# 2025-06-02 00:56:04.615 | INFO     | pyprophet.io.util:print_parquet_tree:312 - Input Parquet Structure:
# └── 📁 data/test_data.oswpq
#     ├── 📁 test_data.oswpq
#     │   ├── 📄 precursors_features.parquet
#     │   └── 📄 transition_features.parquet
# 2025-06-02 00:56:04.762 | INFO     | pyprophet.io._base:_collapse_ipf_peptide_ids:1369 - Collapsed 13 of 6520 rows due to multiple transitions features mapping to different peptidoforms.

# %%
osw_data
# Out:
#                feature_id  transition_id  area_intensity  apex_intensity  \
# 0    -9078977811506172301           3269         65086.0          8571.0
# 1    -9078977811506172301           3274         28118.0          3659.0
# 2    -9078977811506172301           3275         18643.0          2935.0
# 3    -9078977811506172301           3276         10931.0          1571.0
# 4    -9078977811506172301           3277         20099.0          3158.0
# ...                   ...            ...             ...             ...
# 6502  9218597765662578237           5082         20865.0          2567.0
# 6503  9218597765662578237           5083         14438.0          3050.0
# 6504  9218597765662578237           5085         15499.0          3234.0
# 6505  9218597765662578237          14329          1649.0           262.0
# 6506  9218597765662578237          14337           120.0            20.0
#
#       var_log_intensity  var_xcorr_coelution  main_var_xcorr_shape  \
# 0              11.08350                  0.0              0.988488
# 1              10.24420                  0.0              0.775015
# 2               9.83323                  0.0              0.987159
# 3               9.29936                  0.0              0.976596
# 4               9.90843                  0.0              0.980119
# ...                 ...                  ...                   ...
# 6502            9.94583                  1.0              0.803354
# 6503            9.57762                  0.0              0.992086
# 6504            9.64853                  0.0              0.991741
# 6505            7.40792                  0.5              0.690893
# 6506            4.78749                  7.0              0.272361
#
#       var_log_sn_score  var_massdev_score  var_isotope_correlation_score  \
# 0              2.28037           1.339620                       0.986416
# 1              2.96661          15.881300                       0.982047
# 2              2.74691           3.497610                       0.936990
# 3              2.54362           5.398260                       0.982335
# 4              2.72363           2.800890                       0.997938
# ...                ...                ...                            ...
# 6502           1.33504           1.619140                       0.392923
# 6503           3.27596           1.975210                       0.988239
# 6504           4.85533           0.332315                       0.997599
# 6505           0.91223           5.561800                       0.828575
# 6506           2.99573           7.958980                       0.234603
#
#       var_isotope_overlap_score  decoy               run_id  precursor_id  \
# 0                      0.380002      0 -8670811102654834151            69
# 1                      0.064225      0 -8670811102654834151            69
# 2                      0.082794      0 -8670811102654834151            69
# 3                      0.084023      0 -8670811102654834151            69
# 4                      0.090880      0 -8670811102654834151            69
# ...                         ...    ...                  ...           ...
# 6502                   0.301909      0 -8670811102654834151           134
# 6503                   0.079672      0 -8670811102654834151           134
# 6504                   0.088435      0 -8670811102654834151           134
# 6505                   0.309160      1 -8670811102654834151           134
# 6506                   0.000000      1 -8670811102654834151           134
#
#        exp_rt  precursor_charge  product_charge  \
# 0     2163.91                 2               1
# 1     2163.91                 2               1
# 2     2163.91                 2               1
# 3     2163.91                 2               1
# 4     2163.91                 2               1
# ...       ...               ...             ...
# 6502  2889.39                 2               2
# 6503  2889.39                 2               1
# 6504  2889.39                 2               1
# 6505  2889.39                 2               1
# 6506  2889.39                 2               1
#
#                                                group_id
# 0     -8670811102654834151_-9078977811506172301_69_3269
# 1     -8670811102654834151_-9078977811506172301_69_3274
# 2     -8670811102654834151_-9078977811506172301_69_3275
# 3     -8670811102654834151_-9078977811506172301_69_3276
# 4     -8670811102654834151_-9078977811506172301_69_3277
# ...                                                 ...
# 6502  -8670811102654834151_9218597765662578237_134_5082
# 6503  -8670811102654834151_9218597765662578237_134_5083
# 6504  -8670811102654834151_9218597765662578237_134_5085
# 6505  -8670811102654834151_9218597765662578237_134_1...
# 6506  -8670811102654834151_9218597765662578237_134_1...
#
# [6507 rows x 18 columns]

# %%
grouped = osw_data.groupby('group_id').size().reset_index(name='count')
filtered_groups = grouped[grouped['count'] > 1]
filtered_groups
# Out:
# Empty DataFrame
# Columns: [group_id, count]
# Index: []

# %%
# parquet_data[~parquet_data['run_id'].isna()]
parquet_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # parquet_data[~parquet_data['run_id'].isna()]
# ----> 2 parquet_data
#
# NameError: name 'parquet_data' is not defined

# %%
parquet_data[ parquet_data['group_id']=='-8670811102654834151_7058704691706873957_267_8638' ]
# Out:
#                                                group_id           feature_id  \
# 5739  -8670811102654834151_7058704691706873957_267_8638  7058704691706873957
#
#      ipf_peptide_id  decoy  run_id  transition_id  var_log_intensity  \
# 5739     [853, 854]      0     NaN           8638            10.2522
#
#       var_xcorr_coelution  main_var_xcorr_shape  var_log_sn_score  \
# 5739                  0.0              0.907322           1.67417
#
#       var_massdev_score  var_isotope_correlation_score  \
# 5739            2.10102                       0.997484
#
#       var_isotope_overlap_score  precursor_charge  transition_charge
# 5739                   0.207736                 2                  1

# %%
split_parquet_data
# Out:
#                                                group_id           feature_id  \
# 0     -8670811102654834151_-9078977811506172301_69_3269 -9078977811506172301
# 1     -8670811102654834151_-9078977811506172301_69_3274 -9078977811506172301
# 2     -8670811102654834151_-9078977811506172301_69_3275 -9078977811506172301
# 3     -8670811102654834151_-9078977811506172301_69_3276 -9078977811506172301
# 4     -8670811102654834151_-9078977811506172301_69_3277 -9078977811506172301
# ...                                                 ...                  ...
# 6502  -8670811102654834151_9218597765662578237_134_5082  9218597765662578237
# 6503  -8670811102654834151_9218597765662578237_134_5083  9218597765662578237
# 6504  -8670811102654834151_9218597765662578237_134_5085  9218597765662578237
# 6505  -8670811102654834151_9218597765662578237_134_1...  9218597765662578237
# 6506  -8670811102654834151_9218597765662578237_134_1...  9218597765662578237
#
#      ipf_peptide_id  decoy               run_id  transition_id  \
# 0             [305]      0 -8670811102654834151           3269
# 1             [305]      0 -8670811102654834151           3274
# 2             [305]      0 -8670811102654834151           3275
# 3             [305]      0 -8670811102654834151           3276
# 4             [305]      0 -8670811102654834151           3277
# ...             ...    ...                  ...            ...
# 6502          [513]      0 -8670811102654834151           5082
# 6503          [513]      0 -8670811102654834151           5083
# 6504          [513]      0 -8670811102654834151           5085
# 6505          [476]      1 -8670811102654834151          14329
# 6506          [476]      1 -8670811102654834151          14337
#
#       area_intensity  var_log_intensity  var_xcorr_coelution  \
# 0            65086.0           11.08350                  0.0
# 1            28118.0           10.24420                  0.0
# 2            18643.0            9.83323                  0.0
# 3            10931.0            9.29936                  0.0
# 4            20099.0            9.90843                  0.0
# ...              ...                ...                  ...
# 6502         20865.0            9.94583                  1.0
# 6503         14438.0            9.57762                  0.0
# 6504         15499.0            9.64853                  0.0
# 6505          1649.0            7.40792                  0.5
# 6506           120.0            4.78749                  7.0
#
#       main_var_xcorr_shape  var_log_sn_score  var_massdev_score  \
# 0                 0.988488           2.28037           1.339620
# 1                 0.775015           2.96661          15.881300
# 2                 0.987159           2.74691           3.497610
# 3                 0.976596           2.54362           5.398260
# 4                 0.980119           2.72363           2.800890
# ...                    ...               ...                ...
# 6502              0.803354           1.33504           1.619140
# 6503              0.992086           3.27596           1.975210
# 6504              0.991741           4.85533           0.332315
# 6505              0.690893           0.91223           5.561800
# 6506              0.272361           2.99573           7.958980
#
#       var_isotope_correlation_score  var_isotope_overlap_score  \
# 0                          0.986416                   0.380002
# 1                          0.982047                   0.064225
# 2                          0.936990                   0.082794
# 3                          0.982335                   0.084023
# 4                          0.997938                   0.090880
# ...                             ...                        ...
# 6502                       0.392923                   0.301909
# 6503                       0.988239                   0.079672
# 6504                       0.997599                   0.088435
# 6505                       0.828575                   0.309160
# 6506                       0.234603                   0.000000
#
#       precursor_charge  transition_charge
# 0                    2                  1
# 1                    2                  1
# 2                    2                  1
# 3                    2                  1
# 4                    2                  1
# ...                ...                ...
# 6502                 2                  2
# 6503                 2                  1
# 6504                 2                  1
# 6505                 2                  1
# 6506                 2                  1
#
# [6507 rows x 16 columns]

# %% [markdown]
# # IPF

# %% [markdown]
# SELECT
# SCORE_IPF_PRE_BATCHING.FEATURE_ID,
# SCORE_IPF_PRE_BATCHING.PEPTIDE_ID,
# SCORE_IPF_PRE_BATCHING.PRECURSOR_PEAKGROUP_PEP,
# SCORE_IPF.PRECURSOR_PEAKGROUP_PEP AS PRECURSOR_PEAKGROUP_PEP_2,
# SCORE_IPF_PRE_BATCHING.QVALUE,
# SCORE_IPF.QVALUE AS QVALUE_2,
# SCORE_IPF_PRE_BATCHING.PEP,
# SCORE_IPF.PEP AS PEP_2
# FROM SCORE_IPF_PRE_BATCHING
# FULL JOIN SCORE_IPF ON SCORE_IPF.FEATURE_ID = SCORE_IPF_PRE_BATCHING.FEATURE_ID AND SCORE_IPF.PEPTIDE_ID = SCORE_IPF_PRE_BATCHING.PEPTIDE_ID
# LIMIT 1000;

# %%
def create_reader_config(level, infile, outfile):
    """
    Common config generator to avoid repetition
    """
    return IPFIOConfig(
        infile=infile, outfile=outfile, subsample_ratio=1, context="ipf", level=level, ipf_ms1_scoring = False, ipf_ms2_scoring = False,
    )

# %% [markdown]
# ## Peakgroup-Precursor

# %%
osw_config = create_reader_config(
    "peakgroup_precursor", "data/test_data.osw", "data/test_data.osw"
)
parquet_config = create_reader_config(
    "peakgroup_precursor", "data/test_data.parquet", "data/test_data.parquet"
)
split_parquet_config = create_reader_config(
    "peakgroup_precursor",
    "data/test_data_scored.oswpq",
    "data/test_data_scored.oswpq",
)

osw_reader = ReaderDispatcher.get_reader(osw_config)
parquet_reader = ReaderDispatcher.get_reader(parquet_config)
split_parquet_reader = ReaderDispatcher.get_reader(split_parquet_config)

# osw_data = osw_reader.read("peakgroup_precursor").sort_values(by=["feature_id", "ms2_peakgroup_pep", "ms1_precursor_pep", "ms2_precursor_pep"]).reset_index(drop=True)
# parquet_data = parquet_reader.read("peakgroup_precursor").sort_values(by=["feature_id", "ms2_peakgroup_pep", "ms1_precursor_pep", "ms2_precursor_pep"]).reset_index(drop=True)
split_parquet_data = split_parquet_reader.read("peakgroup_precursor").sort_values(by=["feature_id", "ms2_peakgroup_pep", "ms1_precursor_pep", "ms2_precursor_pep"]).reset_index(drop=True)
# Out:
# 2025-06-21 21:57:17.471 | WARNING  | pyprophet.io.dispatcher:get_reader:101 - Parquet input is experimental. Proceed with caution.
# 2025-06-21 21:57:17.473 | WARNING  | pyprophet.io.dispatcher:get_reader:104 - Split parquet input is experimental. Proceed with caution.
# 2025-06-21 21:57:17.514 | INFO     | pyprophet.io.util:print_parquet_tree:359 - Detected 1 split_parquet run files
# 2025-06-21 21:57:17.516 | INFO     | pyprophet.io.util:print_parquet_tree:360 - Input Parquet Structure:
# └── 📁 data/test_data_scored.oswpq
#     ├── 📁 test_data_scored.oswpq
#     │   ├── 📄 precursors_features.parquet
#     │   └── 📄 transition_features.parquet
# 2025-06-21 21:57:17.533 | INFO     | pyprophet.io.ipf.split_parquet:_read_pyp_peakgroup_precursor:66 - Reading precursor-level data ...

# %%
osw_data
# Out:
#               feature_id  ms2_peakgroup_pep  ms1_precursor_pep  \
# 0   -9078977811506172301  0.003654135376405               <NA>
# 1   -9059007664292712863  0.091383787890556               <NA>
# 2   -9009602369958523731  0.003654135376405               <NA>
# 3   -8990894093332793487  0.003654135376405               <NA>
# 4   -8915955323477460297  0.003654135376405               <NA>
# ..                   ...                ...                ...
# 367  9100151962100689925  0.003654135376405               <NA>
# 368  9138695304810091733  0.003654135376405               <NA>
# 369  9179217567582710769  0.003654135376405               <NA>
# 370  9182851156161074378  0.003654135376405               <NA>
# 371  9218597765662578237  0.003654135376405               <NA>
#
#      ms2_precursor_pep
# 0                 <NA>
# 1                 <NA>
# 2                 <NA>
# 3                 <NA>
# 4                 <NA>
# ..                 ...
# 367               <NA>
# 368               <NA>
# 369               <NA>
# 370               <NA>
# 371               <NA>
#
# [372 rows x 4 columns]

# %%
parquet_data
# Out:
#               feature_id  ms2_peakgroup_pep  ms1_precursor_pep  \
# 0   -9078977811506172301  0.003654135391116               <NA>
# 1   -9059007664292712863  0.091383785009384               <NA>
# 2   -9009602369958523731  0.003654135391116               <NA>
# 3   -8990894093332793487  0.003654135391116               <NA>
# 4   -8915955323477460297  0.003654135391116               <NA>
# ..                   ...                ...                ...
# 367  9100151962100689925  0.003654135391116               <NA>
# 368  9138695304810091733  0.003654135391116               <NA>
# 369  9179217567582710769  0.003654135391116               <NA>
# 370  9182851156161074378  0.003654135391116               <NA>
# 371  9218597765662578237  0.003654135391116               <NA>
#
#      ms2_precursor_pep
# 0                 <NA>
# 1                 <NA>
# 2                 <NA>
# 3                 <NA>
# 4                 <NA>
# ..                 ...
# 367               <NA>
# 368               <NA>
# 369               <NA>
# 370               <NA>
# 371               <NA>
#
# [372 rows x 4 columns]

# %%
split_parquet_data
# Out:
#               feature_id  ms2_peakgroup_pep  ms1_precursor_pep  \
# 0   -9078977811506172301  0.003654135376405               <NA>
# 1   -9059007664292712863  0.091383787890556               <NA>
# 2   -9009602369958523731  0.003654135376405               <NA>
# 3   -8990894093332793487  0.003654135376405               <NA>
# 4   -8915955323477460297  0.003654135376405               <NA>
# ..                   ...                ...                ...
# 367  9100151962100689925  0.003654135376405               <NA>
# 368  9138695304810091733  0.003654135376405               <NA>
# 369  9179217567582710769  0.003654135376405               <NA>
# 370  9182851156161074378  0.003654135376405               <NA>
# 371  9218597765662578237  0.003654135376405               <NA>
#
#      ms2_precursor_pep
# 0                 <NA>
# 1                 <NA>
# 2                 <NA>
# 3                 <NA>
# 4                 <NA>
# ..                 ...
# 367               <NA>
# 368               <NA>
# 369               <NA>
# 370               <NA>
# 371               <NA>
#
# [372 rows x 4 columns]

# %%
split_parquet_data
# Out:
#               feature_id  ms2_peakgroup_pep  ms1_precursor_pep  \
# 0   -9078977811506172301  0.003142319081467               <NA>
# 1   -9059007664292712863  0.361467984298225               <NA>
# 2   -9009602369958523731  0.003142319081467               <NA>
# 3   -8990894093332793487  0.003142319081467               <NA>
# 4   -8915955323477460297  0.003142319081467               <NA>
# ..                   ...                ...                ...
# 384  9100151962100689925  0.003142319081467               <NA>
# 385  9138695304810091733  0.003142319081467               <NA>
# 386  9179217567582710769  0.003142319081467               <NA>
# 387  9182851156161074378  0.003142319081467               <NA>
# 388  9218597765662578237  0.003142319081467               <NA>
#
#      ms2_precursor_pep
# 0                 <NA>
# 1                 <NA>
# 2                 <NA>
# 3                 <NA>
# 4                 <NA>
# ..                 ...
# 384               <NA>
# 385               <NA>
# 386               <NA>
# 387               <NA>
# 388               <NA>
#
# [389 rows x 4 columns]

# %% [markdown]
# ## Transition

# %%
osw_config = create_reader_config(
    "transition", "data/test_data.osw", "data/test_data.osw"
)
parquet_config = create_reader_config(
    "transition", "data/test_data.parquet", "data/test_data.parquet"
)
split_parquet_config = create_reader_config(
    "transition",
    "data/test_data_scored.oswpq",
    "data/test_data_scored.oswpq",
)

osw_reader = ReaderDispatcher.get_reader(osw_config)
parquet_reader = ReaderDispatcher.get_reader(parquet_config)
split_parquet_reader = ReaderDispatcher.get_reader(split_parquet_config)

# osw_data = osw_reader.read("transition").sort_values(by=["feature_id", "transition_id", "pep"]).reset_index(drop=True)
# parquet_data = parquet_reader.read("transition").sort_values(by=["feature_id", "transition_id", "pep"]).reset_index(drop=True)
split_parquet_data = split_parquet_reader.read("transition").sort_values(by=["feature_id", "transition_id", "pep"]).reset_index(drop=True)
# Out:
# 2025-06-20 00:15:55.448 | WARNING  | pyprophet.io.dispatcher:get_reader:101 - Parquet input is experimental. Proceed with caution.
# 2025-06-20 00:15:55.448 | WARNING  | pyprophet.io.dispatcher:get_reader:104 - Split parquet input is experimental. Proceed with caution.
# 2025-06-20 00:15:55.456 | INFO     | pyprophet.io.util:print_parquet_tree:359 - Detected 1 split_parquet run files
# 2025-06-20 00:15:55.457 | INFO     | pyprophet.io.util:print_parquet_tree:360 - Input Parquet Structure:
# └── 📁 data/test_data_scored.oswpq
#     ├── 📁 test_data_scored.oswpq
#     │   ├── 📄 precursors_features.parquet
#     │   └── 📄 transition_features.parquet
# 2025-06-20 00:15:55.461 | INFO     | pyprophet.io.ipf.split_parquet:_read_pyp_transition:173 - Reading peptidoform-level data ...
# 2025-06-20 00:15:55.468 | DEBUG    | pyprophet.io.ipf.split_parquet:_read_pyp_transition:335 - Processing features 0-1000: 1000 features
# 2025-06-20 00:15:55.501 | DEBUG    | pyprophet.io.ipf.split_parquet:_read_pyp_transition:406 - Processed features 0-1000: 2344 rows
# 2025-06-20 00:15:55.502 | DEBUG    | pyprophet.io.ipf.split_parquet:_read_pyp_transition:335 - Processing features 1000-2000: 1000 features
# 2025-06-20 00:15:55.526 | DEBUG    | pyprophet.io.ipf.split_parquet:_read_pyp_transition:406 - Processed features 1000-2000: 2864 rows
# 2025-06-20 00:15:55.527 | DEBUG    | pyprophet.io.ipf.split_parquet:_read_pyp_transition:335 - Processing features 2000-3000: 1000 features
# 2025-06-20 00:15:55.553 | DEBUG    | pyprophet.io.ipf.split_parquet:_read_pyp_transition:406 - Processed features 2000-3000: 3004 rows
# 2025-06-20 00:15:55.554 | DEBUG    | pyprophet.io.ipf.split_parquet:_read_pyp_transition:335 - Processing features 3000-3410: 410 features
# 2025-06-20 00:15:55.576 | DEBUG    | pyprophet.io.ipf.split_parquet:_read_pyp_transition:406 - Processed features 3000-3410: 1156 rows
# 2025-06-20 00:15:55.579 | INFO     | pyprophet.io.ipf.split_parquet:_read_pyp_transition:413 - Loaded total 9321 transition-peptidoform entries

# %%
osw_data
# Out:
#                feature_id  transition_id               pep  peptide_id  \
# 0    -9078977811506172301           3275 0.007548884271154         305
# 1    -9078977811506172301           3275 0.007548884271154          -1
# 2    -9078977811506172301           3276 0.013393521510058         305
# 3    -9078977811506172301           3276 0.013393521510058          -1
# 4    -9078977811506172301           3277 0.004850020600794         305
# ...                   ...            ...               ...         ...
# 9310  9218597765662578237           5082 0.292798299079015          -1
# 9311  9218597765662578237           5083 0.000743727340380         513
# 9312  9218597765662578237           5083 0.000743727340380          -1
# 9313  9218597765662578237           5085 0.000743727340380         513
# 9314  9218597765662578237           5085 0.000743727340380          -1
#
#                  bmask  num_peptidoforms
# 0    1.000000000000000                 1
# 1    0.000000000000000                 1
# 2    1.000000000000000                 1
# 3    0.000000000000000                 1
# 4    1.000000000000000                 1
# ...                ...               ...
# 9310 0.000000000000000                 1
# 9311 1.000000000000000                 1
# 9312 0.000000000000000                 1
# 9313 1.000000000000000                 1
# 9314 0.000000000000000                 1
#
# [9315 rows x 6 columns]

# %%
parquet_data
# Out:
#                feature_id  transition_id               pep  peptide_id  \
# 0    -9078977811506172301           3275 0.007548884488642         305
# 1    -9078977811506172301           3275 0.007548884488642          -1
# 2    -9078977811506172301           3276 0.013393520377576         305
# 3    -9078977811506172301           3276 0.013393520377576          -1
# 4    -9078977811506172301           3277 0.004850020632148         305
# ...                   ...            ...               ...         ...
# 9310  9218597765662578237           5082 0.292809933423996          -1
# 9311  9218597765662578237           5083 0.000743727316149         513
# 9312  9218597765662578237           5083 0.000743727316149          -1
# 9313  9218597765662578237           5085 0.000743727316149         513
# 9314  9218597765662578237           5085 0.000743727316149          -1
#
#                  bmask  num_peptidoforms
# 0    1.000000000000000                 1
# 1    0.000000000000000                 1
# 2    1.000000000000000                 1
# 3    0.000000000000000                 1
# 4    1.000000000000000                 1
# ...                ...               ...
# 9310 0.000000000000000                 1
# 9311 1.000000000000000                 1
# 9312 0.000000000000000                 1
# 9313 1.000000000000000                 1
# 9314 0.000000000000000                 1
#
# [9315 rows x 6 columns]

# %%
split_parquet_data
# Out:
#                feature_id  transition_id               pep  peptide_id  \
# 0    -9078977811506172301           3275 0.007548884271154         305
# 1    -9078977811506172301           3275 0.007548884271154          -1
# 2    -9078977811506172301           3276 0.013393521510058         305
# 3    -9078977811506172301           3276 0.013393521510058          -1
# 4    -9078977811506172301           3277 0.004850020600794         305
# ...                   ...            ...               ...         ...
# 9310  9218597765662578237           5082 0.292798299079015          -1
# 9311  9218597765662578237           5083 0.000743727340380         513
# 9312  9218597765662578237           5083 0.000743727340380          -1
# 9313  9218597765662578237           5085 0.000743727340380         513
# 9314  9218597765662578237           5085 0.000743727340380          -1
#
#                  bmask  num_peptidoforms
# 0    1.000000000000000                 1
# 1    0.000000000000000                 1
# 2    1.000000000000000                 1
# 3    0.000000000000000                 1
# 4    1.000000000000000                 1
# ...                ...               ...
# 9310 0.000000000000000                 1
# 9311 1.000000000000000                 1
# 9312 0.000000000000000                 1
# 9313 1.000000000000000                 1
# 9314 0.000000000000000                 1
#
# [9315 rows x 6 columns]

# %%
split_parquet_data
# Out:
#                feature_id  transition_id               pep  peptide_id  bmask  \
# 0    -9078977811506172301           3275 0.007527684725314         305      1
# 1    -9078977811506172301           3275 0.007527684725314          -1      0
# 2    -9078977811506172301           3276 0.013336601138495         305      1
# 3    -9078977811506172301           3276 0.013336601138495          -1      0
# 4    -9078977811506172301           3277 0.004828594421420         305      1
# ...                   ...            ...               ...         ...    ...
# 9316  9218597765662578237           5082 0.293300720162134          -1      0
# 9317  9218597765662578237           5083 0.000740899956141         513      1
# 9318  9218597765662578237           5083 0.000740899956141          -1      0
# 9319  9218597765662578237           5085 0.000740899956141         513      1
# 9320  9218597765662578237           5085 0.000740899956141          -1      0
#
#       num_peptidoforms
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ...                ...
# 9316                 1
# 9317                 1
# 9318                 1
# 9319                 1
# 9320                 1
#
# [9321 rows x 6 columns]

# %% [markdown]
# ## Test batching

# %%
file = "/home/singjc/Documents/github/synth_phospho/Justin_Synth_PhosPep/results/fragpipe_oswbench_20220512/data/arycal/merged.osw"

osw_config = create_reader_config(
    "peakgroup_precursor", file, file
)

# split_parquet_config = create_reader_config(
#     "peakgroup_precursor",
#     "data/test_data_scored.oswpq",
#     "data/test_data_scored.oswpq",
# )

osw_reader = ReaderDispatcher.get_reader(osw_config)
# split_parquet_reader = ReaderDispatcher.get_reader(split_parquet_config)

osw_data = osw_reader.read("peakgroup_precursor").sort_values(by=["feature_id", "ms2_peakgroup_pep", "ms1_precursor_pep", "ms2_precursor_pep"]).reset_index(drop=True)
# split_parquet_data = split_parquet_reader.read("peakgroup_precursor").sort_values(by=["feature_id", "ms2_peakgroup_pep", "ms1_precursor_pep", "ms2_precursor_pep"]).reset_index(drop=True)
# Out:
# 2025-06-26 17:21:39.925 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...

# %%
config = osw_config
reader = osw_reader
batch_size = config.batch_size
peptide_ids = reader.read(level="peptide_ids")["peptide_id"].unique()

print(f"Batch size: {batch_size}")
print(f"Number of unique peptides: {len(peptide_ids)}")
# Out:
# Batch size: 100000
# Number of unique peptides: 684

# %%
from pyprophet.ipf import precursor_inference, peptidoform_inference

# %%
precursor_table = reader.read(
            level="peakgroup_precursor", peptide_ids=peptide_ids
        )
precursor_data = precursor_inference(
    precursor_table,
    config.ipf_ms1_scoring,
    config.ipf_ms2_scoring,
    config.ipf_max_precursor_pep,
    config.ipf_max_precursor_peakgroup_pep,
)
# Out:
# 2025-06-26 11:28:37.769 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# 2025-06-26 11:28:38.079 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.

# %%
precursor_data = precursor_data.sort_values('feature_id')
precursor_data
# Out:
#               feature_id  precursor_peakgroup_pep
# 69  -9078977811506172301        0.003142319081467
# 14  -9059007664292712863        0.361467984298225
# 71  -9009602369958523731        0.003142319081467
# 333 -8990894093332793487        0.003142319081467
# 270 -8915955323477460297        0.003142319081467
# ..                   ...                      ...
# 82   9100151962100689925        0.003142319081467
# 97   9138695304810091733        0.003142319081467
# 145  9179217567582710769        0.003142319081467
# 314  9182851156161074378        0.003142319081467
# 131  9218597765662578237        0.003142319081467
#
# [389 rows x 2 columns]

# %%
batch_size = 100

# Iterate over peptide_ids in batches to avoid memory issues
if batch_size > 0:
    peptide_id_batches = [
        peptide_ids[i : i + batch_size]
        for i in range(0, len(peptide_ids), batch_size)
    ]
else:
    peptide_id_batches = [peptide_ids]

all_peptidoform_data = []
for peptide_ids_batch in peptide_id_batches:
    print(
        f"Processing peptide IDs batch: {peptide_ids_batch[0]} to {peptide_ids_batch[-1]} of {len(peptide_ids)}..."
    )

    # precursor level
    precursor_table = reader.read(
        level="peakgroup_precursor", peptide_ids=peptide_ids_batch
    )
    tmp_precursor_data = precursor_inference(
        precursor_table,
        config.ipf_ms1_scoring,
        config.ipf_ms2_scoring,
        config.ipf_max_precursor_pep,
        config.ipf_max_precursor_peakgroup_pep,
    )
    
    all_peptidoform_data.append(tmp_precursor_data)
    

precursor_data_batched = pd.concat(all_peptidoform_data, ignore_index=True)
# Out:
# 2025-06-26 11:32:42.573 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 32 to 838 of 684...
# 2025-06-26 11:32:42.865 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:32:43.046 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 924 to 1108 of 684...
# 2025-06-26 11:32:43.441 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:32:43.548 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 1115 to 1295 of 684...
# 2025-06-26 11:32:43.955 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# Processing peptide IDs batch: 1299 to 557 of 684...
# 2025-06-26 11:32:44.186 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# 2025-06-26 11:32:44.565 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:32:44.707 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 483 to 1279 of 684...
# 2025-06-26 11:32:44.953 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:32:45.063 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 1310 to 54 of 684...
# 2025-06-26 11:32:45.277 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:32:45.419 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 105 to 1343 of 684...
# 2025-06-26 11:32:45.730 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.

# %%
precursor_data_batched = precursor_data_batched.sort_values('feature_id')
precursor_data_batched
# Out:
#               feature_id  precursor_peakgroup_pep
# 58  -9078977811506172301        0.003142319081467
# 11  -9059007664292712863        0.361467984298225
# 60  -9009602369958523731        0.003142319081467
# 197 -8990894093332793487        0.003142319081467
# 324 -8915955323477460297        0.003142319081467
# ..                   ...                      ...
# 72   9100151962100689925        0.003142319081467
# 126  9138695304810091733        0.003142319081467
# 169  9179217567582710769        0.003142319081467
# 100  9182851156161074378        0.003142319081467
# 158  9218597765662578237        0.003142319081467
#
# [389 rows x 2 columns]

# %%
merged_df = pd.merge(precursor_data, precursor_data_batched, on='feature_id', how='outer', indicator=True)
merged_df
# Out:
#               feature_id  precursor_peakgroup_pep_x  \
# 0   -9078977811506172301          0.003142319081467
# 1   -9059007664292712863          0.361467984298225
# 2   -9009602369958523731          0.003142319081467
# 3   -8990894093332793487          0.003142319081467
# 4   -8915955323477460297          0.003142319081467
# ..                   ...                        ...
# 384  9100151962100689925          0.003142319081467
# 385  9138695304810091733          0.003142319081467
# 386  9179217567582710769          0.003142319081467
# 387  9182851156161074378          0.003142319081467
# 388  9218597765662578237          0.003142319081467
#
#      precursor_peakgroup_pep_y _merge
# 0            0.003142319081467   both
# 1            0.361467984298225   both
# 2            0.003142319081467   both
# 3            0.003142319081467   both
# 4            0.003142319081467   both
# ..                         ...    ...
# 384          0.003142319081467   both
# 385          0.003142319081467   both
# 386          0.003142319081467   both
# 387          0.003142319081467   both
# 388          0.003142319081467   both
#
# [389 rows x 4 columns]

# %%
merged_df[merged_df['_merge'] != 'both']
# Out:
# Empty DataFrame
# Columns: [feature_id, precursor_peakgroup_pep_x, precursor_peakgroup_pep_y, _merge]
# Index: []

# %% [markdown]
# ## Transition

# %%
peptidoform_table = reader.read(
            level="transition", peptide_ids=peptide_ids
        )
peptidoform_data = peptidoform_inference(
            peptidoform_table,
            precursor_data,
            config.ipf_grouped_fdr,
            config.propagate_signal_across_runs,
            config.across_run_confidence_threshold,
        )
peptidoform_data = peptidoform_data.sort_values('feature_id')
peptidoform_data
# Out:
# 2025-06-26 11:38:26.542 | INFO     | pyprophet.io.ipf.osw:_read_pyp_transition_duckdb:335 - Info: Reading peptidoform-level data ...
# 2025-06-26 11:38:26.917 | INFO     | pyprophet.ipf:peptidoform_inference:414 - Preparing peptidoform-level data ...
# 2025-06-26 11:38:26.989 | INFO     | pyprophet.ipf:peptidoform_inference:420 - Conducting peptidoform-level inference ...
#               feature_id  hypothesis  likelihood_prior    likelihood_sum  \
# 0   -9078977811506172301          -1 0.000000000000000 0.486771939725330
# 1   -9078977811506172301         305 0.486771939725330 0.486771939725330
# 2   -9009602369958523731          -1 0.000000000000000 0.357278539044749
# 3   -9009602369958523731         309 0.357278539044749 0.357278539044749
# 4   -8990894093332793487          -1 0.000000000000000 0.715743158621281
# ..                   ...         ...               ...               ...
# 659  9179217567582710769         366 0.801162190369319 0.801162190369319
# 660  9182851156161074378          -1 0.000000000000000 0.141255891796635
# 661  9182851156161074378         975 0.141255891796635 0.141255891796635
# 662  9218597765662578237          -1 0.000000000000000 0.640933354407969
# 663  9218597765662578237         513 0.640933354407969 0.640933354407969
#
#             posterior               pep            qvalue  \
# 0   0.000000000000000 1.000000000000000 0.500000000000000
# 1   1.000000000000000 0.000000000000000 0.000000000000000
# 2   0.000000000000000 1.000000000000000 0.500000000000000
# 3   1.000000000000000 0.000000000000000 0.000000000000000
# 4   0.000000000000000 1.000000000000000 0.500000000000000
# ..                ...               ...               ...
# 659 1.000000000000000 0.000000000000000 0.000000000000000
# 660 0.000000000000000 1.000000000000000 0.500000000000000
# 661 1.000000000000000 0.000000000000000 0.000000000000000
# 662 0.000000000000000 1.000000000000000 0.500000000000000
# 663 1.000000000000000 0.000000000000000 0.000000000000000
#
#      precursor_peakgroup_pep
# 0          0.003142319081467
# 1          0.003142319081467
# 2          0.003142319081467
# 3          0.003142319081467
# 4          0.003142319081467
# ..                       ...
# 659        0.003142319081467
# 660        0.003142319081467
# 661        0.003142319081467
# 662        0.003142319081467
# 663        0.003142319081467
#
# [664 rows x 8 columns]

# %%
batch_size = 100

# Iterate over peptide_ids in batches to avoid memory issues
if batch_size > 0:
    peptide_id_batches = [
        peptide_ids[i : i + batch_size]
        for i in range(0, len(peptide_ids), batch_size)
    ]
else:
    peptide_id_batches = [peptide_ids]

all_peptidoform_data = []
for peptide_ids_batch in peptide_id_batches:
    print(
        f"Processing peptide IDs batch: {peptide_ids_batch[0]} to {peptide_ids_batch[-1]} of {len(peptide_ids)}..."
    )

    # precursor level
    precursor_table = reader.read(
        level="peakgroup_precursor", peptide_ids=peptide_ids_batch
    )
    tmp_precursor_data = precursor_inference(
        precursor_table,
        config.ipf_ms1_scoring,
        config.ipf_ms2_scoring,
        config.ipf_max_precursor_pep,
        config.ipf_max_precursor_peakgroup_pep,
    )
    
    peptidoform_table = reader.read(
            level="transition", peptide_ids=peptide_ids_batch
        )
    
    tmp_peptidoform_data = peptidoform_inference(
            peptidoform_table,
            tmp_precursor_data,
            config.ipf_grouped_fdr,
            config.propagate_signal_across_runs,
            config.across_run_confidence_threshold,
        )
    
    all_peptidoform_data.append(tmp_peptidoform_data)
    

peptidoform_data_batched = pd.concat(all_peptidoform_data, ignore_index=True)
peptidoform_data_batched = peptidoform_data_batched.sort_values('feature_id')
peptidoform_data_batched
# Out:
# 2025-06-26 11:40:58.509 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 32 to 838 of 684...
# 2025-06-26 11:40:58.891 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:40:59.084 | INFO     | pyprophet.io.ipf.osw:_read_pyp_transition_duckdb:335 - Info: Reading peptidoform-level data ...
# 2025-06-26 11:40:59.586 | INFO     | pyprophet.ipf:peptidoform_inference:414 - Preparing peptidoform-level data ...
# 2025-06-26 11:40:59.617 | INFO     | pyprophet.ipf:peptidoform_inference:420 - Conducting peptidoform-level inference ...
# 2025-06-26 11:40:59.783 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 924 to 1108 of 684...
# 2025-06-26 11:41:00.075 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:41:00.208 | INFO     | pyprophet.io.ipf.osw:_read_pyp_transition_duckdb:335 - Info: Reading peptidoform-level data ...
# 2025-06-26 11:41:00.758 | INFO     | pyprophet.ipf:peptidoform_inference:414 - Preparing peptidoform-level data ...
# 2025-06-26 11:41:00.782 | INFO     | pyprophet.ipf:peptidoform_inference:420 - Conducting peptidoform-level inference ...
# 2025-06-26 11:41:00.948 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 1115 to 1295 of 684...
# 2025-06-26 11:41:01.208 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:41:01.317 | INFO     | pyprophet.io.ipf.osw:_read_pyp_transition_duckdb:335 - Info: Reading peptidoform-level data ...
# 2025-06-26 11:41:01.789 | INFO     | pyprophet.ipf:peptidoform_inference:414 - Preparing peptidoform-level data ...
# 2025-06-26 11:41:01.829 | INFO     | pyprophet.ipf:peptidoform_inference:420 - Conducting peptidoform-level inference ...
# 2025-06-26 11:41:02.058 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 1299 to 557 of 684...
# 2025-06-26 11:41:02.295 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:41:02.424 | INFO     | pyprophet.io.ipf.osw:_read_pyp_transition_duckdb:335 - Info: Reading peptidoform-level data ...
# 2025-06-26 11:41:02.696 | INFO     | pyprophet.ipf:peptidoform_inference:414 - Preparing peptidoform-level data ...
# 2025-06-26 11:41:02.718 | INFO     | pyprophet.ipf:peptidoform_inference:420 - Conducting peptidoform-level inference ...
# 2025-06-26 11:41:02.935 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 483 to 1279 of 684...
# 2025-06-26 11:41:03.332 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:41:03.523 | INFO     | pyprophet.io.ipf.osw:_read_pyp_transition_duckdb:335 - Info: Reading peptidoform-level data ...
# 2025-06-26 11:41:03.835 | INFO     | pyprophet.ipf:peptidoform_inference:414 - Preparing peptidoform-level data ...
# 2025-06-26 11:41:03.850 | INFO     | pyprophet.ipf:peptidoform_inference:420 - Conducting peptidoform-level inference ...
# 2025-06-26 11:41:04.036 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# Processing peptide IDs batch: 1310 to 54 of 684...
# 2025-06-26 11:41:04.352 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:41:04.557 | INFO     | pyprophet.io.ipf.osw:_read_pyp_transition_duckdb:335 - Info: Reading peptidoform-level data ...
# 2025-06-26 11:41:04.899 | INFO     | pyprophet.ipf:peptidoform_inference:414 - Preparing peptidoform-level data ...
# 2025-06-26 11:41:04.926 | INFO     | pyprophet.ipf:peptidoform_inference:420 - Conducting peptidoform-level inference ...
# Processing peptide IDs batch: 105 to 1343 of 684...
# 2025-06-26 11:41:05.184 | INFO     | pyprophet.io.ipf.osw:_read_pyp_peakgroup_precursor_duckdb:214 - Reading precursor-level data ...
# 2025-06-26 11:41:05.600 | INFO     | pyprophet.ipf:precursor_inference:376 - Skipping precursor-level inference.
# 2025-06-26 11:41:05.771 | INFO     | pyprophet.io.ipf.osw:_read_pyp_transition_duckdb:335 - Info: Reading peptidoform-level data ...
# 2025-06-26 11:41:06.105 | INFO     | pyprophet.ipf:peptidoform_inference:414 - Preparing peptidoform-level data ...
# 2025-06-26 11:41:06.123 | INFO     | pyprophet.ipf:peptidoform_inference:420 - Conducting peptidoform-level inference ...
#               feature_id           hypothesis  likelihood_prior  \
# 0   -9078977811506172301   -1.000000000000000 0.000000000000000
# 1   -9078977811506172301  305.000000000000000 0.486771939725330
# 3   -9009602369958523731  309.000000000000000 0.357278539044749
# 2   -9009602369958523731   -1.000000000000000 0.000000000000000
# 197 -8990894093332793487 1169.000000000000000 0.715743158621281
# ..                   ...                  ...               ...
# 382  9179217567582710769   -1.000000000000000 0.000000000000000
# 194  9182851156161074378   -1.000000000000000 0.000000000000000
# 195  9182851156161074378  975.000000000000000 0.141255891796635
# 384  9218597765662578237   -1.000000000000000 0.000000000000000
# 385  9218597765662578237  513.000000000000000 0.640933354407969
#
#        likelihood_sum         posterior               pep            qvalue  \
# 0   0.486771939725330 0.000000000000000 1.000000000000000 0.500000000000000
# 1   0.486771939725330 1.000000000000000 0.000000000000000 0.000000000000000
# 3   0.357278539044749 1.000000000000000 0.000000000000000 0.000000000000000
# 2   0.357278539044749 0.000000000000000 1.000000000000000 0.500000000000000
# 197 0.715743158621281 1.000000000000000 0.000000000000000 0.000000000000000
# ..                ...               ...               ...               ...
# 382 0.801162190369319 0.000000000000000 1.000000000000000 0.500000000000000
# 194 0.141255891796635 0.000000000000000 1.000000000000000 0.500000000000000
# 195 0.141255891796635 1.000000000000000 0.000000000000000 0.000000000000000
# 384 0.640933354407969 0.000000000000000 1.000000000000000 0.500000000000000
# 385 0.640933354407969 1.000000000000000 0.000000000000000 0.000000000000000
#
#      precursor_peakgroup_pep
# 0          0.003142319081467
# 1          0.003142319081467
# 3          0.003142319081467
# 2          0.003142319081467
# 197        0.003142319081467
# ..                       ...
# 382        0.003142319081467
# 194        0.003142319081467
# 195        0.003142319081467
# 384        0.003142319081467
# 385        0.003142319081467
#
# [664 rows x 8 columns]

# %%
merged_df = pd.merge(precursor_data, precursor_data_batched, on='feature_id', how='outer', indicator=True)
merged_df
# Out:
#               feature_id  precursor_peakgroup_pep_x  \
# 0   -9078977811506172301          0.003142319081467
# 1   -9059007664292712863          0.361467984298225
# 2   -9009602369958523731          0.003142319081467
# 3   -8990894093332793487          0.003142319081467
# 4   -8915955323477460297          0.003142319081467
# ..                   ...                        ...
# 384  9100151962100689925          0.003142319081467
# 385  9138695304810091733          0.003142319081467
# 386  9179217567582710769          0.003142319081467
# 387  9182851156161074378          0.003142319081467
# 388  9218597765662578237          0.003142319081467
#
#      precursor_peakgroup_pep_y _merge
# 0            0.003142319081467   both
# 1            0.361467984298225   both
# 2            0.003142319081467   both
# 3            0.003142319081467   both
# 4            0.003142319081467   both
# ..                         ...    ...
# 384          0.003142319081467   both
# 385          0.003142319081467   both
# 386          0.003142319081467   both
# 387          0.003142319081467   both
# 388          0.003142319081467   both
#
# [389 rows x 4 columns]

# %%
merged_df[merged_df['_merge'] != 'both']
# Out:
# Empty DataFrame
# Columns: [feature_id, precursor_peakgroup_pep_x, precursor_peakgroup_pep_y, _merge]
# Index: []
